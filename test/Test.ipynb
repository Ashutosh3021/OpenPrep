# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"Leetcode/leetcode_problems_with_descriptions.csv")
print(df.sample(5))
# Out:
#         id                                              title  \
# 1004  1005            Maximize Sum Of Array After K Negations
# 42      43                                   Multiply Strings
# 3609  3610          Minimum Number of Primes to Sum to Target
# 2428  2429                                       Minimize XOR
# 2136  2137  Pour Water Between Buckets to Make Water Level...
#
#                                                    slug difficulty  is_paid  \
# 1004            maximize-sum-of-array-after-k-negations       Easy    False
# 42                                     multiply-strings     Medium    False
# 3609          minimum-number-of-primes-to-sum-to-target     Medium     True
# 2428                                       minimize-xor     Medium    False
# 2136  pour-water-between-buckets-to-make-water-level...     Medium     True
#
#                                                  tags  \
# 1004                           Array, Greedy, Sorting
# ...
